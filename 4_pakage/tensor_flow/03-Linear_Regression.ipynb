# %% [markdown]
# ## 3. Linear Regression/

# %% [markdown]
# 1. 변수 정의
# 2. 모델 정의
#
# 3. Loss function 정의
# 4. optimizer 정의
#
# 5. Session 실행

# %%
import tensorflow as tf

# %% [markdown]
# ### 변수 정의

# %%
x_data = [1, 2, 3]
y_data = [1, 2, 3]

# %%
W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.random_uniform([1], -1.0, 1.0))

# %%
X = tf.placeholder(tf.float32, name = "X")
Y = tf.placeholder(tf.float32, name = "Y")

# %% [markdown]
# ### Model : y = W * x + b

# %%
# y = W * x + b
equation = W * X + b

# %% [markdown]
# ### Loss function

# %%
# mean(h - Y) ** 2
cost = tf.reduce_mean(tf.square(equation - Y))

# %% [markdown]
# ### optimizer : Gradient descent

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.1)

# %%
train_op = optimizer.minimize(cost)

# %% [markdown]
# ### Session 실행

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for step in range(100):
        _, cost_val = sess.run([train_op, cost], feed_dict={X : x_data, Y : y_data})
        
        print(step, cost_val, sess.run(W), sess.run(b))
        
    print("==== Test ====")
    print("X: 5, Y: ", sess.run(equation, feed_dict={X:5}))
    print("X: 2.5, Y: ", sess.run(equation, feed_dict={X:2.5}))
# Out:
# 0 8.97742 [ 0.91399586] [ 0.54014796]
# 1 0.140458 [ 0.77820718] [ 0.46652001]
# 2 0.0333207 [ 0.7986058] [ 0.46193314]
# 3 0.0305379 [ 0.80180049] [ 0.45010421]
# 4 0.0290729 [ 0.80674499] [ 0.43936315]
# 5 0.0276918 [ 0.81137109] [ 0.42879254]
# 6 0.0263764 [ 0.81590778] [ 0.41848561]
# 7 0.0251235 [ 0.82033294] [ 0.40842539]
# 8 0.0239301 [ 0.82465208] [ 0.39860713]
# 9 0.0227934 [ 0.82886732] [ 0.38902488]
# 10 0.0217107 [ 0.83298117] [ 0.37967297]
# 11 0.0206794 [ 0.8369962] [ 0.37054592]
# 12 0.0196972 [ 0.84091473] [ 0.36163825]
# 13 0.0187615 [ 0.84473896] [ 0.3529447]
# 14 0.0178703 [ 0.8484714] [ 0.34446019]
# 15 0.0170215 [ 0.85211402] [ 0.33617958]
# 16 0.0162129 [ 0.85566908] [ 0.32809806]
# 17 0.0154428 [ 0.85913867] [ 0.32021081]
# 18 0.0147093 [ 0.86252493] [ 0.31251317]
# 19 0.0140106 [ 0.86582977] [ 0.30500057]
# 20 0.0133451 [ 0.86905509] [ 0.29766855]
# 21 0.0127112 [ 0.87220293] [ 0.2905128]
# 22 0.0121074 [ 0.87527508] [ 0.28352907]
# 23 0.0115323 [ 0.87827337] [ 0.27671322]
# 24 0.0109845 [ 0.88119966] [ 0.27006125]
# 25 0.0104627 [ 0.88405544] [ 0.26356915]
# 26 0.00996572 [ 0.88684267] [ 0.25723314]
# 27 0.00949235 [ 0.8895629] [ 0.25104943]
# 28 0.00904144 [ 0.89221776] [ 0.24501437]
# 29 0.00861196 [ 0.89480871] [ 0.23912439]
# 30 0.0082029 [ 0.8973375] [ 0.23337604]
# 31 0.00781326 [ 0.89980537] [ 0.22776581]
# 32 0.00744212 [ 0.90221399] [ 0.22229049]
# 33 0.00708861 [ 0.90456474] [ 0.2169468]
# 34 0.00675191 [ 0.90685892] [ 0.21173154]
# 35 0.00643118 [ 0.90909803] [ 0.20664167]
# 36 0.0061257 [ 0.9112832] [ 0.20167413]
# 37 0.00583472 [ 0.91341591] [ 0.19682603]
# 38 0.00555756 [ 0.91549736] [ 0.19209446]
# 39 0.00529357 [ 0.91752869] [ 0.18747661]
# 40 0.00504212 [ 0.91951126] [ 0.18296981]
# 41 0.00480263 [ 0.9214462] [ 0.17857136]
# 42 0.00457449 [ 0.92333454] [ 0.1742786]
