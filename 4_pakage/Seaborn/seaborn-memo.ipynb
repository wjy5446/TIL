# %% [markdown]
# # Seaborn

# %% [markdown]
# Seaborn은 matplotlib을 기반으로 하는 Python 고급 시각화 라이브러리

# %% [markdown]
# ## 스타일

# %% [markdown]
# seaborn 임포트 할 시에 seaborn의 스타일이 적용된다.
# ```
# sns.set() : seaborn을 설정한다.
# ```
#
# ### set style
# ```
# sns.set_style('whitegrid') : 틱 스타일 변형
# sns.set_color_codes() : 컬러 문자열을 바꾼다.
# ```

# %% [markdown]
# ### remove axes

# %% [markdown]
# ```
# sns.despline()
# ```

# %% [markdown]
# ### set context

# %% [markdown]
# ```
# sns.set_context("paper") : 얇은 선
# sns.set_context("notebook") : 굵은 선
# sns.set_context("talk") : 매우 굵은 선
# sns.set_context("poster") : 매우매우 굵은 선
# ```

# %% [markdown]
# ## color palettes

# %% [markdown]
# ###  종류
# ```
# sns.color_palette() : 기본 파렛트
# sns.color_palette("hls", 8)
# sns.color_palette(color, 8)
# ```
#
# ### 확인
# ```
# sns.palplot(palette) : 팔레트 도표로 확인
# ```
#
# ### 설정
# ```
# sns.set_palette("hls", 8) : 팔레트 지정
# ```

# %% [markdown]
# ## sample 불러오기

# %% [markdown]
# ```
# sns.load_dataset('iris') : 붓꽃 데이터
# sns.load_dataset('titanic') : 타이타닉호 데이터
# sns.load_dataset('tips') : 팁 데이터
# sns.load_dataset('flights') : 여객운송 데이터
# ```

# %% [markdown]
# ## 1차원 실수 분포 플롯

# %% [markdown]
# 1차원의 실수 값의 분포를 확인할 때 사용되는 플롯

# %%
iris = sns.load_dataset('iris')
x = iris.sepal_length.values

# %% [markdown]
# **rugplot**
# - 선분 위에 실제 데이터 출력

# %%
sns.rugplot(x)

# %% [markdown]
# **kdeplot**
# - rug에 커널 함수를 겹쳐 그리는 함수

# %%
sns.kdeplot(x)

# %% [markdown]
# **distplot**
# - histogram 출력, 여기에 rug, kde 출력

# %%
sns.distplot(x, rug = True, kde = True)

# %% [markdown]
# ## 1차원 카테고리 데이터 확인

# %%
titanic = sns.load_dataset('titanic')

# %% [markdown]
# **countplot**
# - 카테고리 값별로 데이터 갯수 확인

# %%
sns.countplot(x= "class", data = titanic)

# %% [markdown]
# ## 다차원 데이터
#
# - 분석하는 데이터가 모두 실수인 경우
# - 분석하는 데이터가 모두 카테고리인 경우
# - 분석하는 데이터가 모두 실수와 카테고리 값이 섞여 있는 경우

# %% [markdown]
# ## 2차원 실수형 데이터

# %% [markdown]
# ## Joint plot

# %% [markdown]
# - 데이터가 2차원 연속적인 실수값 (hist + scatter)

# %%
sns.jointplot(x = "sepal_length", y = "sepal_width", data = iris)

# %% [markdown]
# - hist와 scatter 모두 커널로 표시

# %%
sns.jointplot(x="sepal_length", y="sepal_width", data = iris, kind = "kde")

# %% [markdown]
# ## 다차원 실수형 데이터

# %% [markdown]
# ## pairplot

# %% [markdown]
# - 3차원 이상의 실수형 데이터를 나타내는 것

# %%
sns.pairplot(data = iris, hue = "species", markers = ["o", "s", "*"])

# %% [markdown]
# ## 2차원 카테고리 데이터

# %% [markdown]
# ### heatmap

# %% [markdown]
# - 2차원 카테고리 값을 출력 할 때, 사용

# %%
sns.heatmap([[3, 4, 5], [6, 8, 9]], annot = True, fmt = "1.1f")

# %% [markdown]
# ## lmplot

# %% [markdown]
# - 두 그래프의 scatter와 선형 관계를 보여준다.

# %%
sns.lmplot(x = "sepal_length", y = "sepal_width", data = iris, hue = "species", markers = ["o", "*", "^"])
